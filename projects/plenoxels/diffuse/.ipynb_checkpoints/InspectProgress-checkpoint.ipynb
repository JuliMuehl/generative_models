# %%
import torch
import numpy as np
import os
import json
from tqdm import tqdm
from PIL import Image
image_dir = "test_images"
with open(os.path.join(image_dir, "camera_poses.json")) as f:
    camera_positions = np.array(json.load(f)["camera_positions"])
num_poses = len(camera_positions)
colors = [] 
dirs = []
for i in tqdm(range(num_poses)):
    with Image.open(os.path.join(image_dir, f"img{i}.png")) as img:
        img = np.array(img).reshape(-1, len(img.getbands())) / 255.0
        colors.append(img[:, :3])
    with Image.open(os.path.join(image_dir, f"dirs{i}.png")) as img:
        img_dirs = np.array(img) / 255.0 * 2.0 - 1.0
        img_dirs = img_dirs.reshape(-1, 3)
        dirs.append(img_dirs)

#Due to the 8bit quantization of the png file the directions aren't quite normalized anymore so we renormalize them here
dirs = np.array(dirs)
dirs = dirs/np.linalg.norm(np.array(dirs), axis=-1)[:, :, None]
origins = np.repeat(camera_positions[:, None, :], dirs.shape[1], axis=1)
device = "xpu" if torch.xpu.is_available() else "cpu"
#converting to np.array from list[np.array] first instead of directly converting to torch.tensor improves speed
colors = torch.tensor(np.array(colors), dtype=torch.float).to(device)
dirs   = torch.tensor(dirs, dtype=torch.float).to(device)
origins = torch.tensor(origins, dtype=torch.float).to(device)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 92.69it/s]

# %%
model = torch.load("diffoxels.pt", weights_only=False)
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(2,3)

plt.subplots_adjust(hspace=0.0, wspace=0.0)
with torch.no_grad():
    for axtarget, axtest  in zip(ax[0], ax[1]):
        i = np.random.randint(num_poses)
        img = (model(origins[i].view(-1, 3), dirs[i].view(-1, 3)).view(512, 512, 3) * 255).to(torch.uint8).detach().to("cpu").numpy()
        axtest.imshow(img)
        axtest.axis("off")
        axtarget.axis("off")
        axtarget.imshow(colors[i].view(512, 512, 3).to("cpu").numpy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 fig, ax = plt.subplots(2,3)
#       5
# ----> 6 plt.subplots_adjust(bottom=0.0, top=0.0, hspace=0.0, wspace=0.0)
#       7 with torch.no_grad():
#       8     for axtarget, axtest  in zip(ax[0], ax[1]):
#       9         i = np.random.randint(num_poses)
#
# File ~/.venv/lib/python3.14/site-packages/matplotlib/pyplot.py:2823, in subplots_adjust(left, bottom, right, top, wspace, hspace)
#    2814 @_copy_docstring_and_deprecators(Figure.subplots_adjust)
#    2815 def subplots_adjust(
#    2816     left: float | None = None,
#    (...)   2821     hspace: float | None = None,
#    2822 ) -> None:
# -> 2823     gcf().subplots_adjust(
#    2824         left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace
#    2825     )
#
# File ~/.venv/lib/python3.14/site-packages/matplotlib/figure.py:1358, in FigureBase.subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    1353     _api.warn_external(
#    1354         "This figure was using a layout engine that is "
#    1355         "incompatible with subplots_adjust and/or tight_layout; "
#    1356         "not calling subplots_adjust.")
#    1357     return
# -> 1358 self.subplotpars.update(left, bottom, right, top, wspace, hspace)
#    1359 for ax in self.axes:
#    1360     if ax.get_subplotspec() is not None:
#
# File ~/.venv/lib/python3.14/site-packages/matplotlib/gridspec.py:776, in SubplotParams.update(self, left, bottom, right, top, wspace, hspace)
#     773     raise ValueError('left cannot be >= right')
#     774 if ((bottom if bottom is not None else self.bottom)
#     775         >= (top if top is not None else self.top)):
# --> 776     raise ValueError('bottom cannot be >= top')
#     777 if left is not None:
#     778     self.left = left
#
# ValueError: bottom cannot be >= top
